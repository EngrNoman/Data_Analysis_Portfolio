# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
file_path = 'cleaned_taxi_data.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# 📌 Step 1: Load & Inspect the Data

# %%
df.head(5)

# %%
df.info()

# %%
df.isnull().sum()
# Out:
# TRIP_ID          0
# CALL_TYPE        0
# ORIGIN_CALL      0
# ORIGIN_STAND     0
# TAXI_ID          0
# TIMESTAMP        0
# DAY_TYPE         0
# MISSING_DATA     0
# POLYLINE         0
# trip_duration    0
# hour             0
# day_of_week      0
# rush_hour        0
# dtype: int64

# %%
df.describe()
# Out:
#             TRIP_ID       TAXI_ID  trip_duration          hour     rush_hour
# count  1.631890e+06  1.631890e+06   1.631890e+06  1.631890e+06  1.631890e+06
# mean   1.388613e+18  2.000035e+07   6.392556e+02  1.188612e+01  2.852061e-01
# std    9.192885e+15  2.108939e+02   3.216857e+02  6.273893e+00  4.515127e-01
# min    1.372637e+18  2.000000e+07   0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.380704e+18  2.000017e+07   4.050000e+02  7.000000e+00  0.000000e+00
# 50%    1.388491e+18  2.000034e+07   6.000000e+02  1.200000e+01  0.000000e+00
# 75%    1.396757e+18  2.000052e+07   8.400000e+02  1.700000e+01  1.000000e+00
# max    1.404173e+18  2.000098e+07   1.575000e+03  2.300000e+01  1.000000e+00

# %% [markdown]
# 📌 Step 2: Exploratory Data Analysis (EDA)

# %% [markdown]
# 1️⃣ Univariate Analysis

# %%
plt.figure(figsize =(10,5))
sns.histplot(df['TAXI_ID'] , bins=50 , kde=True)
plt.title("Distribution of Taxi Usage")
# Out:
# Text(0.5, 1.0, 'Distribution of Taxi Usage')

# %%
plt.figure(figsize=(7,4))
sns.countplot(x=df['CALL_TYPE'] , palette='viridis')
plt.title('Call Type Distribution')
# Out:
# C:\Users\Engr Noman Mahmood\AppData\Local\Temp\ipykernel_3280\1542957112.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['CALL_TYPE'] , palette='viridis')
# Text(0.5, 1.0, 'Call Type Distribution')

# %%
plt.figure(figsize=(7,4))
sns.countplot(x=df['DAY_TYPE'], palette = 'coolwarm')
plt.title('Day Type Distribution')
# Out:
# C:\Users\Engr Noman Mahmood\AppData\Local\Temp\ipykernel_3280\1289107843.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['DAY_TYPE'], palette = 'coolwarm')
# Text(0.5, 1.0, 'Day Type Distribution')

# %% [raw]
# 2️⃣ Bivariate Analysis

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='CALL_TYPE' , hue="DAY_TYPE" , data=df)
plt.title('Trip Demand Based on Call Type and Day Type')
# Out:
# Text(0.5, 1.0, 'Trip Demand Based on Call Type and Day Type')

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x="DAY_TYPE", y="TAXI_ID", data=df)
plt.title("Taxi Distribution Based on Day Type")
# Out:
# Text(0.5, 1.0, 'Taxi Distribution Based on Day Type')

# %% [raw]
# 📌 Step 3: Find Trends in Time (Temporal Analysis)

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x="DAY_TYPE", y="hour", data=df)
plt.title("Time of Day for Different Day Types")
plt.show()
